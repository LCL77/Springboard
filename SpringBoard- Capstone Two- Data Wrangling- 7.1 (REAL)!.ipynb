# %% [markdown]
# # Capstone Two- Data Wrangling - 7.6
#
#
# # Questions:
# 1. Why are the Happiness Score coming up as NaN
#
#
# # Idea
#
# take happiest 3 countries and least happy 3 countires in the past 4 years and look up datasets for:
#
# 1. ethnic diversity
# 2. money spent on education (% of GDP)
# 4. Ratio of men to women
# 5. How many women are in government/Do the happiest countriest have more women or men in positions of power
#
# * Keep in mind the least happy nations may not have all the necessary information due to their standing in the world and what leads them to be so low in the ranking.
# * I would like to gather this infomration for all countries BUT for now is there a great difference between this informatoin in the most happiest and least and is there a correlation of some sort.
#
# # To Do:
#
# 1. look at others projects see if you can figure out a cleaner code/easier way of:
# - making sure the name convention is the same, putting in same columns
# - putting all the datasets together
# - sorting by happiness rank or happines score (which is a better indicator)
# - viewing year, score, country etc.
#
# 2. find top 3 happiest countries, top 3 least happy countries
#
# 3. bring in outside information about
# - ethnic diversity
# - money spent on education (% of GDP)
# - Ratio of men to women
# - How many women are in government/Do the happiest countriest have more women or men in positions of power
#
#
# # Resources
#
# - https://towardsdatascience.com/happiness-and-life-satisfaction-ecdc7d0ab9a5
# - https://www.kaggle.com/unsdsn/world-happiness?select=2019.csv
# - https://happiness-report.s3.amazonaws.com/2020/WHR20.pdf
# - https://www.kaggle.com/roshansharma/world-happiness-report

# %% [markdown]
# # Directions
#
# - Don’t spend lots of time searching for data just work on it. Thats whats important
# - set a time - 20 minutes per search for each project idea
# - search specific terms
# - see which are most feasible
# - what are the specific questions that you can answer from the kaggle data
# - let this opportunity show your technical tool kit /know youre stuff -down pat and THEN be more creative after.
# - look at guided capstone 1 to see the questions and what the layout is.
# - LOOK FOR BIGGER DATASET or (but much more difficult use multiple)
# - Have multiple notebooks

# %% [markdown]
# # Data Collection
#
# Goal: Organize your data to streamline the next steps of your
# capstone

# %%
#Data loading

import pandas as pd
import matplotlib as plt
import seaborn as sns
import os

import pandas as pd
import os
import pickle
import numpy as np 
import json
import statistics

data_2020= pd.read_csv('2020.csv')

data_2019= pd.read_csv('2019.csv')

data_2018= pd.read_csv('2018.csv')

data_2017= pd.read_csv('2017.csv')

data_2016= pd.read_csv('2016.csv')

data_2015= pd.read_csv('2015.csv')

# %% [markdown]
# # Check List
#
# Make your data tidy.
# - Each variable forms a column
# - Each observation forms a row
# - Each type of observational unit forms a table
# - Column Name
# - Data Type (numeric, categorical, timestamp, etc)
# - Description of Column
# - Count or percent per unique values or codes (including NA)
# - The range of values or codes

# %% [markdown]
# # Data Cleaning
#
# Goal: Clean up the data in order to prepare it for the next steps of
# your project.
#
# Hint: don’t forget about the following awesome Python functions for data cleaning, which make life a whole lot easier:
# - loc[] - filter your data by label
# - iloc[] - filter your data by indexes
# - apply() - execute a function across an axis of a DataFrame
# - drop() - drop columns from a DataFrame
# - is_unique() - check if a column is a unique identifier
# - Series methods, such as str.contains(), which can be used to check if a certain substring occurs in a string of a Series, and - str.extract(), which can be used to extract capture groups with a certain regex (or regular expression ) pattern
# - numPy methods like .where(), to clean columns. Recall that such methods have the structure: np.where(condition, then, else)
# - DataFrame methods to check for null values, such as df.isnull().values.any()

# %%
#look at column headers 2020

data_2020.head()
# Out:
#   Country name Regional indicator    Ladder score  \
# 0      Finland     Western Europe  Happiness Rank
# 1      Denmark     Western Europe  Happiness Rank
# 2  Switzerland     Western Europe  Happiness Rank
# 3      Iceland     Western Europe  Happiness Rank
# 4       Norway     Western Europe  Happiness Rank
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  ...  Perceptions of corruption  \
# 0                      0.949172  ...                   0.195445
# 1                      0.951444  ...                   0.168489
# 2                      0.921337  ...                   0.303728
# 3                      0.948892  ...                   0.711710
# 4                      0.955750  ...                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual  Year
# 0                                 0.477857             2.762835  2020
# 1                                 0.495260             2.432741  2020
# 2                                 0.407946             2.350267  2020
# 3                                 0.144541             2.460688  2020
# 4                                 0.434101             2.168266  2020
#
# [5 rows x 21 columns]

# %%
#look at column headers 2019

data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
#look at column headers 2018

data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
#look at column headers 2017

data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
#look at column headers 2016

data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
#look at column headers 2015

data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
#look at column headers 2020

data_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
# 1                      0.951444    0.066202                   0.168489
# 2                      0.921337    0.105911                   0.303728
# 3                      0.948892    0.246944                   0.711710
# 4                      0.955750    0.134533                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                 0.477857             2.762835
# 1                                 0.495260             2.432741
# 2                                 0.407946             2.350267
# 3                                 0.144541             2.460688
# 4                                 0.434101             2.168266

# %%
#look at info of data
#index = data_2019.index()
#number_of_rows = len(data_2019)
#print(number_of_rows)

data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#look at info of data

data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#look at info of data

data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB

# %%
#look at info of data

data_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB

# %%
#look at info of data

data_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
#look at info of data

data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
#  9   Freedom to make life choices                153 non-null    float64
#  10  Generosity                                  153 non-null    float64
#  11  Perceptions of corruption                   153 non-null    float64
#  12  Ladder score in Dystopia                    153 non-null    float64
#  13  Explained by: Log GDP per capita            153 non-null    float64
#  14  Explained by: Social support                153 non-null    float64
#  15  Explained by: Healthy life expectancy       153 non-null    float64
#  16  Explained by: Freedom to make life choices  153 non-null    float64
#  17  Explained by: Generosity                    153 non-null    float64
#  18  Explained by: Perceptions of corruption     153 non-null    float64
#  19  Dystopia + residual                         153 non-null    float64
# dtypes: float64(18), object(2)
# memory usage: 24.0+ KB

# %% [markdown]
# # Data Definition
#
# Goal: Gain an understanding of your data features to inform the next steps of your project.

# %%
#add the column "Year" to all datasets

data_2015['Year'] = 2015 
data_2016['Year'] = 2016 
data_2017['Year'] = 2017 
data_2018['Year'] = 2018    
data_2019['Year'] = 2019 
data_2020['Year'] = 2020

# %%
#change columns, Country, Region, Happiness Rank, Happiness Score, GDP, Life Expectancy to be the same in all datasets
#https://www.listendata.com/2020/09/How-to-rename-columns-in-Pandas.html
#call rename () method 
##df.rename(columns={'year':'years', 'month':'months' }, inplace = True)

data_2020.rename(columns={'Country name ':'Country','Regional indicator':'Region','Ladder score':'Happiness Score','Logged GDP per capita':'GDP', 'Healthy life expectancy':'Life Expectancy'}, inplace = True)
data_2019.rename(columns={'Country or region':'Country','Overall rank':'Happiness Rank','Score':'Happiness Score','GDP per capita':'GDP','Healthy life expectancy':'Life Expectancy'}, inplace = True)
data_2018.rename(columns={'Country or region':'Country','Overall rank':'Happiness Rank','Score':'Happiness Score','GDP per capita':'GDP','Healthy life expectancy':'Life Expectancy'}, inplace = True)
data_2017.rename(columns={'Country':'Country','Region':'Region','Happiness.Rank':'Happiness Rank','Happiness.Score':'Happiness Score','Economy..GDP.per.Capita.':'GDP','Health..Life.Expectancy.':'Life Expectancy'}, inplace = True)
data_2016.rename(columns={'Country':'Country','Region':'Region','Happiness Rank':'Happiness Rank','Happiness score':'Happiness Score','Economy (GDP per Capita)':'GDP','Health (Life Expectancy)':'Life Expectancy'}, inplace = True)
data_2015.rename(columns={'Country':'Country','Region':'Region','Happiness Rank':'Happiness Rank','Happiness score':'Happiness Score','Economy (GDP per Capita)':'GDP','Health (Life Expectancy)':'Life Expectancy'}, inplace = True)
#2020 doesnt have a "happiness rank column"
#2018 doesnt have a region column same as country

# %%
#concatenate data
# resources- https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html 
    
frames = [data_2020, data_2019, data_2018, data_2017, data_2016, data_2015]
all_happiness_data = pd.concat(frames)

# %%
all_happiness_data.head()
# Out:
#        Country          Region Happiness Score  \
# 0      Finland  Western Europe  Happiness Rank
# 1      Denmark  Western Europe  Happiness Rank
# 2  Switzerland  Western Europe  Happiness Rank
# 3      Iceland  Western Europe  Happiness Rank
# 4       Norway  Western Europe  Happiness Rank
#
#    Standard error of ladder score  upperwhisker  lowerwhisker        GDP  \
# 0                        0.031156      7.869766      7.747634  10.639267
# 1                        0.033492      7.711245      7.579955  10.774001
# 2                        0.035014      7.628528      7.491272  10.979933
# 3                        0.059616      7.621347      7.387653  10.772559
# 4                        0.034837      7.556281      7.419719  11.087804
#
#    Social support  Life Expectancy  Freedom to make life choices  ...  \
# 0        0.954330        71.900825                      0.949172  ...
# 1        0.955991        72.402504                      0.951444  ...
# 2        0.942847        74.102448                      0.921337  ...
# 3        0.974670        73.000000                      0.948892  ...
# 4        0.952487        73.200783                      0.955750  ...
#
#    Whisker.low  Family  Freedom  Trust..Government.Corruption.  \
# 0          NaN     NaN      NaN                            NaN
# 1          NaN     NaN      NaN                            NaN
# 2          NaN     NaN      NaN                            NaN
# 3          NaN     NaN      NaN                            NaN
# 4          NaN     NaN      NaN                            NaN
#
#    Dystopia.Residual  Lower Confidence Interval  Upper Confidence Interval  \
# 0                NaN                        NaN                        NaN
# 1                NaN                        NaN                        NaN
# 2                NaN                        NaN                        NaN
# 3                NaN                        NaN                        NaN
# 4                NaN                        NaN                        NaN
#
#    Trust (Government Corruption)  Dystopia Residual  Standard Error
# 0                            NaN                NaN             NaN
# 1                            NaN                NaN             NaN
# 2                            NaN                NaN             NaN
# 3                            NaN                NaN             NaN
# 4                            NaN                NaN             NaN
#
# [5 rows x 33 columns]

# %%
#all_happiness_data.columns()

all_happiness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 935 entries, 0 to 157
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     935 non-null    object
#  1   Region                                      468 non-null    object
#  2   Happiness Score                             935 non-null    object
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   GDP                                         935 non-null    float64
#  7   Social support                              465 non-null    float64
#  8   Life Expectancy                             935 non-null    float64
#  9   Freedom to make life choices                465 non-null    float64
#  10  Generosity                                  935 non-null    float64
#  11  Perceptions of corruption                   464 non-null    float64
#  12  Ladder score in Dystopia                    153 non-null    float64
#  13  Explained by: Log GDP per capita            153 non-null    float64
#  14  Explained by: Social support                153 non-null    float64
#  15  Explained by: Healthy life expectancy       153 non-null    float64
#  16  Explained by: Freedom to make life choices  153 non-null    float64
#  17  Explained by: Generosity                    153 non-null    float64
#  18  Explained by: Perceptions of corruption     153 non-null    float64
#  19  Dystopia + residual                         153 non-null    float64
#  20  Year                                        935 non-null    int64
#  21  Happiness Rank                              782 non-null    float64
#  22  Whisker.high                                155 non-null    float64
#  23  Whisker.low                                 155 non-null    float64
#  24  Family                                      470 non-null    float64
#  25  Freedom                                     470 non-null    float64
#  26  Trust..Government.Corruption.               155 non-null    float64
#  27  Dystopia.Residual                           155 non-null    float64
#  28  Lower Confidence Interval                   157 non-null    float64
#  29  Upper Confidence Interval                   157 non-null    float64
#  30  Trust (Government Corruption)               315 non-null    float64
#  31  Dystopia Residual                           315 non-null    float64
#  32  Standard Error                              158 non-null    float64
# dtypes: float64(29), int64(1), object(3)
# memory usage: 248.4+ KB

# %%
#CHECKING FOR MISSING DATA
all_happiness_data.isnull().sum()
# Out:
# Country                                         0
# Region                                        467
# Happiness Score                                 0
# Standard error of ladder score                782
# upperwhisker                                  782
# lowerwhisker                                  782
# GDP                                             0
# Social support                                470
# Life Expectancy                                 0
# Freedom to make life choices                  470
# Generosity                                      0
# Perceptions of corruption                     471
# Ladder score in Dystopia                      782
# Explained by: Log GDP per capita              782
# Explained by: Social support                  782
# Explained by: Healthy life expectancy         782
# Explained by: Freedom to make life choices    782
# Explained by: Generosity                      782
# Explained by: Perceptions of corruption       782
# Dystopia + residual                           782
# Year                                            0
# Happiness Rank                                153
# Whisker.high                                  780
# Whisker.low                                   780
# Family                                        465
# Freedom                                       465
# Trust..Government.Corruption.                 780
# Dystopia.Residual                             780
# Lower Confidence Interval                     778
# Upper Confidence Interval                     778
# Trust (Government Corruption)                 620
# Dystopia Residual                             620
# Standard Error                                777
# dtype: int64

# %%
print(all_happiness_data['Happiness Score'])
# Out:
# 0      Happiness Rank
# 1      Happiness Rank
# 2      Happiness Rank
# 3      Happiness Rank
# 4      Happiness Rank
#             ...
# 153             3.465
# 154              3.34
# 155             3.006
# 156             2.905
# 157             2.839
# Name: Happiness Score, Length: 935, dtype: object

# %%
#print(all_happiness_data['Happiness Rank'])
all_happiness_data['Happiness Rank'].isnull().sum()
# Out:
# 153

# %%
all_happiness_data['Happiness Rank'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Happiness Rank, dtype: float64

# %% [markdown]
# # Summary Statistics
# Calculate summary statistics for each of your columns, such as mean, median, mode, standard deviation, range, and number of unique values. What does this tell you about your data? What do you now need to investigate?

# %%
#statistical breakdown of each numerical column

all_happiness_data.describe()
# Out:
#        Standard error of ladder score  upperwhisker  lowerwhisker         GDP  \
# count                      153.000000    153.000000    153.000000  935.000000
# mean                         0.053538      5.578175      5.368304    2.287264
# std                          0.018183      1.096823      1.128631    3.161344
# min                          0.025902      2.628270      2.505530    0.000000
# 25%                          0.040698      4.826248      4.603149    0.695145
# 50%                          0.050606      5.607728      5.430644    1.070000
# 75%                          0.060677      6.363886      6.138881    1.395705
# max                          0.120590      7.869766      7.747634   11.450681
#
#        Social support  Life Expectancy  Freedom to make life choices  \
# count      465.000000       935.000000                    465.000000
# mean         1.078654        11.057834                      0.541931
# std          0.317944        23.799414                      0.222500
# min          0.000000         0.000000                      0.000000
# 25%          0.829204         0.508000                      0.390000
# 50%          1.058000         0.708060                      0.535000
# 75%          1.369000         0.892350                      0.712018
# max          1.644000        76.804581                      0.974998
#
#        Generosity  Perceptions of corruption  Ladder score in Dystopia  ...  \
# count  935.000000                 464.000000              1.530000e+02  ...
# mean     0.180425                   0.316339              1.972317e+00  ...
# std      0.153977                   0.319068              1.336643e-15  ...
# min     -0.300907                   0.000000              1.972317e+00  ...
# 25%      0.098152                   0.064000              1.972317e+00  ...
# 50%      0.183000                   0.138000              1.972317e+00  ...
# 75%      0.262000                   0.672239              1.972317e+00  ...
# max      0.838075                   0.935585              1.972317e+00  ...
#
#        Whisker.low      Family     Freedom  Trust..Government.Corruption.  \
# count   155.000000  470.000000  470.000000                     155.000000
# mean      5.255713    0.990347    0.402828                       0.123120
# std       1.145030    0.318707    0.150356                       0.101661
# min       2.521116    0.000000    0.000000                       0.000000
# 25%       4.374955    0.793000    0.297615                       0.057271
# 50%       5.193152    1.025665    0.418347                       0.089848
# 75%       6.006527    1.228745    0.516850                       0.153296
# max       7.479556    1.610574    0.669730                       0.464308
#
#        Dystopia.Residual  Lower Confidence Interval  \
# count         155.000000                 157.000000
# mean            1.850238                   5.282395
# std             0.500028                   1.148043
# min             0.377914                   2.732000
# 25%             1.591291                   4.327000
# 50%             1.832910                   5.237000
# 75%             2.144654                   6.154000
# max             3.117485                   7.460000
#
#        Upper Confidence Interval  Trust (Government Corruption)  \
# count                 157.000000                     315.000000
# mean                    5.481975                       0.140532
# std                     1.136493                       0.115490
# min                     3.078000                       0.000000
# 25%                     4.465000                       0.061315
# 50%                     5.419000                       0.106130
# 75%                     6.434000                       0.178610
# max                     7.669000                       0.551910
#
#        Dystopia Residual  Standard Error
# count         315.000000      158.000000
# mean            2.212032        0.047885
# std             0.558728        0.017146
# min             0.328580        0.018480
# 25%             1.884135        0.037268
# 50%             2.211260        0.043940
# 75%             2.563470        0.052300
# max             3.837720        0.136930
#
# [8 rows x 30 columns]

# %%
#check statistical summary of Happiness Rank, Happiness Score, GDP, Life Expectancy columns 

all_happiness_data['Happiness Score'].describe()
# Out:
# count                935
# unique               717
# top       Happiness Rank
# freq                 153
# Name: Happiness Score, dtype: object

# %%
#data correlation;
all_happiness_data.corr()
# Out:
#                                             Standard error of ladder score  \
# Standard error of ladder score                                1.000000e+00
# upperwhisker                                                 -4.202380e-01
# lowerwhisker                                                 -4.715483e-01
# GDP                                                          -5.789263e-01
# Social support                                               -5.158812e-01
# Life Expectancy                                              -5.864704e-01
# Freedom to make life choices                                 -2.924977e-01
# Generosity                                                    7.274192e-02
# Perceptions of corruption                                     3.035997e-01
# Ladder score in Dystopia                                     -2.028613e-15
# Explained by: Log GDP per capita                             -5.789263e-01
# Explained by: Social support                                 -5.158812e-01
# Explained by: Healthy life expectancy                        -5.864704e-01
# Explained by: Freedom to make life choices                   -2.924977e-01
# Explained by: Generosity                                      7.274192e-02
# Explained by: Perceptions of corruption                      -3.035997e-01
# Dystopia + residual                                           1.496833e-01
# Year                                                                   NaN
# Happiness Rank                                                         NaN
# Whisker.high                                                           NaN
# Whisker.low                                                            NaN
# Family                                                                 NaN
# Freedom                                                                NaN
# Trust..Government.Corruption.                                          NaN
# Dystopia.Residual                                                      NaN
# Lower Confidence Interval                                              NaN
# Upper Confidence Interval                                              NaN
# Trust (Government Corruption)                                          NaN
# Dystopia Residual                                                      NaN
# Standard Error                                                         NaN
#
#                                             upperwhisker  lowerwhisker  \
# Standard error of ladder score             -4.202380e-01 -4.715483e-01
# upperwhisker                                1.000000e+00  9.983566e-01
# lowerwhisker                                9.983566e-01  1.000000e+00
# GDP                                         7.674834e-01  7.824148e-01
# Social support                              7.590122e-01  7.702008e-01
# Life Expectancy                             7.621089e-01  7.776683e-01
# Freedom to make life choices                5.894104e-01  5.912713e-01
# Generosity                                  7.237907e-02  6.574526e-02
# Perceptions of corruption                  -4.143315e-01 -4.218278e-01
# Ladder score in Dystopia                   -1.897447e-15  2.738435e-15
# Explained by: Log GDP per capita            7.674834e-01  7.824148e-01
# Explained by: Social support                7.590122e-01  7.702008e-01
# Explained by: Healthy life expectancy       7.621089e-01  7.776683e-01
# Explained by: Freedom to make life choices  5.894104e-01  5.912713e-01
# Explained by: Generosity                    7.237908e-02  6.574526e-02
# Explained by: Perceptions of corruption     4.143315e-01  4.218278e-01
# Dystopia + residual                         4.919065e-01  4.685900e-01
# Year                                                 NaN           NaN
# Happiness Rank                                       NaN           NaN
# Whisker.high                                         NaN           NaN
# Whisker.low                                          NaN           NaN
# Family                                               NaN           NaN
# Freedom                                              NaN           NaN
# Trust..Government.Corruption.                        NaN           NaN
# Dystopia.Residual                                    NaN           NaN
# Lower Confidence Interval                            NaN           NaN
# Upper Confidence Interval                            NaN           NaN
# Trust (Government Corruption)                        NaN           NaN
# Dystopia Residual                                    NaN           NaN
# Standard Error                                       NaN           NaN
#
#                                                      GDP  Social support  \
# Standard error of ladder score             -5.789263e-01   -5.158812e-01
# upperwhisker                                7.674834e-01    7.590122e-01
# lowerwhisker                                7.824148e-01    7.702008e-01
# GDP                                         1.000000e+00   -5.109288e-01
# Social support                             -5.109288e-01    1.000000e+00
# Life Expectancy                             9.904796e-01   -5.646339e-01
# Freedom to make life choices                7.844923e-01   -2.344594e-01
# Generosity                                 -5.583396e-01    3.559156e-01
# Perceptions of corruption                   8.887248e-01   -5.247164e-01
# Ladder score in Dystopia                    1.434726e-15    2.757347e-15
# Explained by: Log GDP per capita            1.000000e+00    7.818136e-01
# Explained by: Social support                7.818136e-01    1.000000e+00
# Explained by: Healthy life expectancy       8.484686e-01    7.427441e-01
# Explained by: Freedom to make life choices  4.190187e-01    4.788632e-01
# Explained by: Generosity                   -1.183994e-01   -5.678036e-02
# Explained by: Perceptions of corruption     3.347291e-01    2.105296e-01
# Dystopia + residual                        -6.206306e-02   -2.800699e-03
# Year                                        6.408927e-01   -5.174584e-01
# Happiness Rank                             -7.947906e-01   -7.523724e-01
# Whisker.high                                8.118676e-01             NaN
# Whisker.low                                 8.122675e-01             NaN
# Family                                      5.854490e-01             NaN
# Freedom                                     3.449625e-01             NaN
# Trust..Government.Corruption.               3.509441e-01             NaN
# Dystopia.Residual                           2.422642e-02             NaN
# Lower Confidence Interval                   7.906734e-01             NaN
# Upper Confidence Interval                   7.891404e-01             NaN
# Trust (Government Corruption)               2.948563e-01             NaN
# Dystopia Residual                           7.941126e-02             NaN
# Standard Error                             -2.176508e-01             NaN
#
#                                             Life Expectancy  \
# Standard error of ladder score                -5.864704e-01
# upperwhisker                                   7.621089e-01
# lowerwhisker                                   7.776683e-01
# GDP                                            9.904796e-01
# Social support                                -5.646339e-01
# Life Expectancy                                1.000000e+00
# Freedom to make life choices                   7.731768e-01
# Generosity                                    -5.597455e-01
# Perceptions of corruption                      8.945875e-01
# Ladder score in Dystopia                      -5.890844e-15
# Explained by: Log GDP per capita               8.484686e-01
# Explained by: Social support                   7.427441e-01
# Explained by: Healthy life expectancy          1.000000e+00
# Explained by: Freedom to make life choices     4.488462e-01
# Explained by: Generosity                      -7.185211e-02
# Explained by: Perceptions of corruption        3.538412e-01
# Dystopia + residual                           -3.994777e-02
# Year                                           6.476558e-01
# Happiness Rank                                -7.436546e-01
# Whisker.high                                   7.766345e-01
# Whisker.low                                    7.863849e-01
# Family                                         4.863827e-01
# Freedom                                        3.595660e-01
# Trust..Government.Corruption.                  2.797520e-01
# Dystopia.Residual                              5.496328e-02
# Lower Confidence Interval                      7.691772e-01
# Upper Confidence Interval                      7.607523e-01
# Trust (Government Corruption)                  2.497728e-01
# Dystopia Residual                              2.524820e-02
# Standard Error                                -3.102869e-01
#
#                                             Freedom to make life choices  \
# Standard error of ladder score                             -2.924977e-01
# upperwhisker                                                5.894104e-01
# lowerwhisker                                                5.912713e-01
# GDP                                                         7.844923e-01
# Social support                                             -2.344594e-01
# Life Expectancy                                             7.731768e-01
# Freedom to make life choices                                1.000000e+00
# Generosity                                                 -3.435658e-01
# Perceptions of corruption                                   7.195570e-01
# Ladder score in Dystopia                                   -9.230068e-16
# Explained by: Log GDP per capita                            4.190186e-01
# Explained by: Social support                                4.788632e-01
# Explained by: Healthy life expectancy                       4.488462e-01
# Explained by: Freedom to make life choices                  1.000000e+00
# Explained by: Generosity                                    2.537211e-01
# Explained by: Perceptions of corruption                     4.201445e-01
# Dystopia + residual                                         6.257126e-02
# Year                                                        6.003403e-01
# Happiness Rank                                             -5.264284e-01
# Whisker.high                                                         NaN
# Whisker.low                                                          NaN
# Family                                                               NaN
# Freedom                                                              NaN
# Trust..Government.Corruption.                                        NaN
# Dystopia.Residual                                                    NaN
# Lower Confidence Interval                                            NaN
# Upper Confidence Interval                                            NaN
# Trust (Government Corruption)                                        NaN
# Dystopia Residual                                                    NaN
# Standard Error                                                       NaN
#
#                                               Generosity  \
# Standard error of ladder score              7.274192e-02
# upperwhisker                                7.237907e-02
# lowerwhisker                                6.574526e-02
# GDP                                        -5.583396e-01
# Social support                              3.559156e-01
# Life Expectancy                            -5.597455e-01
# Freedom to make life choices               -3.435658e-01
# Generosity                                  1.000000e+00
# Perceptions of corruption                  -5.746770e-01
# Ladder score in Dystopia                   -2.158034e-17
# Explained by: Log GDP per capita           -1.183994e-01
# Explained by: Social support               -5.678035e-02
# Explained by: Healthy life expectancy      -7.185210e-02
# Explained by: Freedom to make life choices  2.537211e-01
# Explained by: Generosity                    1.000000e+00
# Explained by: Perceptions of corruption     2.784802e-01
# Dystopia + residual                        -2.178495e-02
# Year                                       -4.712355e-01
# Happiness Rank                             -1.177133e-01
# Whisker.high                                1.554620e-01
# Whisker.low                                 1.549037e-01
# Family                                      7.177475e-02
# Freedom                                     3.433889e-01
# Trust..Government.Corruption.               2.941595e-01
# Dystopia.Residual                          -1.166267e-01
# Lower Confidence Interval                   1.580248e-01
# Upper Confidence Interval                   1.554948e-01
# Trust (Government Corruption)               2.894989e-01
# Dystopia Residual                          -1.106315e-01
# Standard Error                             -8.843875e-02
#
#                                             Perceptions of corruption  \
# Standard error of ladder score                           3.035997e-01
# upperwhisker                                            -4.143315e-01
# lowerwhisker                                            -4.218278e-01
# GDP                                                      8.887248e-01
# Social support                                          -5.247164e-01
# Life Expectancy                                          8.945875e-01
# Freedom to make life choices                             7.195570e-01
# Generosity                                              -5.746770e-01
# Perceptions of corruption                                1.000000e+00
# Ladder score in Dystopia                                 6.095487e-17
# Explained by: Log GDP per capita                        -3.347291e-01
# Explained by: Social support                            -2.105296e-01
# Explained by: Healthy life expectancy                   -3.538412e-01
# Explained by: Freedom to make life choices              -4.201445e-01
# Explained by: Generosity                                -2.784802e-01
# Explained by: Perceptions of corruption                 -1.000000e+00
# Dystopia + residual                                      1.785091e-02
# Year                                                     7.921139e-01
# Happiness Rank                                          -3.615352e-01
# Whisker.high                                                      NaN
# Whisker.low                                                       NaN
# Family                                                            NaN
# Freedom                                                           NaN
# Trust..Government.Corruption.                                     NaN
# Dystopia.Residual                                                 NaN
# Lower Confidence Interval                                         NaN
# Upper Confidence Interval                                         NaN
# Trust (Government Corruption)                                     NaN
# Dystopia Residual                                                 NaN
# Standard Error                                                    NaN
#
#                                             Ladder score in Dystopia  ...  \
# Standard error of ladder score                         -2.028613e-15  ...
# upperwhisker                                           -1.897447e-15  ...
# lowerwhisker                                            2.738435e-15  ...
# GDP                                                     1.434726e-15  ...
# Social support                                          2.757347e-15  ...
# Life Expectancy                                        -5.890844e-15  ...
# Freedom to make life choices                           -9.230068e-16  ...
# Generosity                                             -2.158034e-17  ...
# Perceptions of corruption                               6.095487e-17  ...
# Ladder score in Dystopia                                1.000000e+00  ...
# Explained by: Log GDP per capita                        4.027003e-16  ...
# Explained by: Social support                            2.876219e-16  ...
# Explained by: Healthy life expectancy                   8.939304e-16  ...
# Explained by: Freedom to make life choices              5.947679e-16  ...
# Explained by: Generosity                                6.646846e-18  ...
# Explained by: Perceptions of corruption                 2.531942e-16  ...
# Dystopia + residual                                    -1.190895e-15  ...
# Year                                                             NaN  ...
# Happiness Rank                                                   NaN  ...
# Whisker.high                                                     NaN  ...
# Whisker.low                                                      NaN  ...
# Family                                                           NaN  ...
# Freedom                                                          NaN  ...
# Trust..Government.Corruption.                                    NaN  ...
# Dystopia.Residual                                                NaN  ...
# Lower Confidence Interval                                        NaN  ...
# Upper Confidence Interval                                        NaN  ...
# Trust (Government Corruption)                                    NaN  ...
# Dystopia Residual                                                NaN  ...
# Standard Error                                                   NaN  ...
#
#                                             Whisker.low    Family   Freedom  \
# Standard error of ladder score                      NaN       NaN       NaN
# upperwhisker                                        NaN       NaN       NaN
# lowerwhisker                                        NaN       NaN       NaN
# GDP                                            0.812267  0.585449  0.344962
# Social support                                      NaN       NaN       NaN
# Life Expectancy                                0.786385  0.486383  0.359566
# Freedom to make life choices                        NaN       NaN       NaN
# Generosity                                     0.154904  0.071775  0.343389
# Perceptions of corruption                           NaN       NaN       NaN
# Ladder score in Dystopia                            NaN       NaN       NaN
# Explained by: Log GDP per capita                    NaN       NaN       NaN
# Explained by: Social support                        NaN       NaN       NaN
# Explained by: Healthy life expectancy               NaN       NaN       NaN
# Explained by: Freedom to make life choices          NaN       NaN       NaN
# Explained by: Generosity                            NaN       NaN       NaN
# Explained by: Perceptions of corruption             NaN       NaN       NaN
# Dystopia + residual                                 NaN       NaN       NaN
# Year                                                NaN  0.251134 -0.054697
# Happiness Rank                                -0.991533 -0.637627 -0.547627
# Whisker.high                                   0.998036  0.750934  0.569907
# Whisker.low                                    1.000000  0.753767  0.569808
# Family                                         0.753767  1.000000  0.425377
# Freedom                                        0.569808  0.425377  1.000000
# Trust..Government.Corruption.                  0.431223  0.231841  0.499183
# Dystopia.Residual                              0.471505  0.070506  0.081926
# Lower Confidence Interval                           NaN  0.741523  0.566857
# Upper Confidence Interval                           NaN  0.736184  0.566203
# Trust (Government Corruption)                       NaN  0.205060  0.492875
# Dystopia Residual                                   NaN  0.053264  0.034829
# Standard Error                                      NaN -0.120728 -0.129773
#
#                                             Trust..Government.Corruption.  \
# Standard error of ladder score                                        NaN
# upperwhisker                                                          NaN
# lowerwhisker                                                          NaN
# GDP                                                              0.350944
# Social support                                                        NaN
# Life Expectancy                                                  0.279752
# Freedom to make life choices                                          NaN
# Generosity                                                       0.294159
# Perceptions of corruption                                             NaN
# Ladder score in Dystopia                                              NaN
# Explained by: Log GDP per capita                                      NaN
# Explained by: Social support                                          NaN
# Explained by: Healthy life expectancy                                 NaN
# Explained by: Freedom to make life choices                            NaN
# Explained by: Generosity                                              NaN
# Explained by: Perceptions of corruption                               NaN
# Dystopia + residual                                                   NaN
# Year                                                                  NaN
# Happiness Rank                                                  -0.405842
# Whisker.high                                                     0.426459
# Whisker.low                                                      0.431223
# Family                                                           0.231841
# Freedom                                                          0.499183
# Trust..Government.Corruption.                                    1.000000
# Dystopia.Residual                                               -0.022755
# Lower Confidence Interval                                             NaN
# Upper Confidence Interval                                             NaN
# Trust (Government Corruption)                                         NaN
# Dystopia Residual                                                     NaN
# Standard Error                                                        NaN
#
#                                             Dystopia.Residual  \
# Standard error of ladder score                            NaN
# upperwhisker                                              NaN
# lowerwhisker                                              NaN
# GDP                                                  0.024226
# Social support                                            NaN
# Life Expectancy                                      0.054963
# Freedom to make life choices                              NaN
# Generosity                                          -0.116627
# Perceptions of corruption                                 NaN
# Ladder score in Dystopia                                  NaN
# Explained by: Log GDP per capita                          NaN
# Explained by: Social support                              NaN
# Explained by: Healthy life expectancy                     NaN
# Explained by: Freedom to make life choices                NaN
# Explained by: Generosity                                  NaN
# Explained by: Perceptions of corruption                   NaN
# Dystopia + residual                                       NaN
# Year                                                      NaN
# Happiness Rank                                      -0.484506
# Whisker.high                                         0.478824
# Whisker.low                                          0.471505
# Family                                               0.070506
# Freedom                                              0.081926
# Trust..Government.Corruption.                       -0.022755
# Dystopia.Residual                                    1.000000
# Lower Confidence Interval                                 NaN
# Upper Confidence Interval                                 NaN
# Trust (Government Corruption)                             NaN
# Dystopia Residual                                         NaN
# Standard Error                                            NaN
#
#                                             Lower Confidence Interval  \
# Standard error of ladder score                                    NaN
# upperwhisker                                                      NaN
# lowerwhisker                                                      NaN
# GDP                                                          0.790673
# Social support                                                    NaN
# Life Expectancy                                              0.769177
# Freedom to make life choices                                      NaN
# Generosity                                                   0.158025
# Perceptions of corruption                                         NaN
# Ladder score in Dystopia                                          NaN
# Explained by: Log GDP per capita                                  NaN
# Explained by: Social support                                      NaN
# Explained by: Healthy life expectancy                             NaN
# Explained by: Freedom to make life choices                        NaN
# Explained by: Generosity                                          NaN
# Explained by: Perceptions of corruption                           NaN
# Dystopia + residual                                               NaN
# Year                                                              NaN
# Happiness Rank                                              -0.994928
# Whisker.high                                                      NaN
# Whisker.low                                                       NaN
# Family                                                       0.741523
# Freedom                                                      0.566857
# Trust..Government.Corruption.                                     NaN
# Dystopia.Residual                                                 NaN
# Lower Confidence Interval                                    1.000000
# Upper Confidence Interval                                    0.997919
# Trust (Government Corruption)                                0.404840
# Dystopia Residual                                            0.538793
# Standard Error                                                    NaN
#
#                                             Upper Confidence Interval  \
# Standard error of ladder score                                    NaN
# upperwhisker                                                      NaN
# lowerwhisker                                                      NaN
# GDP                                                          0.789140
# Social support                                                    NaN
# Life Expectancy                                              0.760752
# Freedom to make life choices                                      NaN
# Generosity                                                   0.155495
# Perceptions of corruption                                         NaN
# Ladder score in Dystopia                                          NaN
# Explained by: Log GDP per capita                                  NaN
# Explained by: Social support                                      NaN
# Explained by: Healthy life expectancy                             NaN
# Explained by: Freedom to make life choices                        NaN
# Explained by: Generosity                                          NaN
# Explained by: Perceptions of corruption                           NaN
# Dystopia + residual                                               NaN
# Year                                                              NaN
# Happiness Rank                                              -0.995525
# Whisker.high                                                      NaN
# Whisker.low                                                       NaN
# Family                                                       0.736184
# Freedom                                                      0.566203
# Trust..Government.Corruption.                                     NaN
# Dystopia.Residual                                                 NaN
# Lower Confidence Interval                                    0.997919
# Upper Confidence Interval                                    1.000000
# Trust (Government Corruption)                                0.398775
# Dystopia Residual                                            0.548164
# Standard Error                                                    NaN
#
#                                             Trust (Government Corruption)  \
# Standard error of ladder score                                        NaN
# upperwhisker                                                          NaN
# lowerwhisker                                                          NaN
# GDP                                                              0.294856
# Social support                                                        NaN
# Life Expectancy                                                  0.249773
# Freedom to make life choices                                          NaN
# Generosity                                                       0.289499
# Perceptions of corruption                                             NaN
# Ladder score in Dystopia                                              NaN
# Explained by: Log GDP per capita                                      NaN
# Explained by: Social support                                          NaN
# Explained by: Healthy life expectancy                                 NaN
# Explained by: Freedom to make life choices                            NaN
# Explained by: Generosity                                              NaN
# Explained by: Perceptions of corruption                               NaN
# Dystopia + residual                                                   NaN
# Year                                                            -0.025142
# Happiness Rank                                                  -0.378864
# Whisker.high                                                          NaN
# Whisker.low                                                           NaN
# Family                                                           0.205060
# Freedom                                                          0.492875
# Trust..Government.Corruption.                                         NaN
# Dystopia.Residual                                                     NaN
# Lower Confidence Interval                                        0.404840
# Upper Confidence Interval                                        0.398775
# Trust (Government Corruption)                                    1.000000
# Dystopia Residual                                               -0.023504
# Standard Error                                                  -0.178325
#
#                                             Dystopia Residual  Standard Error
# Standard error of ladder score                            NaN             NaN
# upperwhisker                                              NaN             NaN
# lowerwhisker                                              NaN             NaN
# GDP                                                  0.079411       -0.217651
# Social support                                            NaN             NaN
# Life Expectancy                                      0.025248       -0.310287
# Freedom to make life choices                              NaN             NaN
# Generosity                                          -0.110632       -0.088439
# Perceptions of corruption                                 NaN             NaN
# Ladder score in Dystopia                                  NaN             NaN
# Explained by: Log GDP per capita                          NaN             NaN
# Explained by: Social support                              NaN             NaN
# Explained by: Healthy life expectancy                     NaN             NaN
# Explained by: Freedom to make life choices                NaN             NaN
# Explained by: Generosity                                  NaN             NaN
# Explained by: Perceptions of corruption                   NaN             NaN
# Dystopia + residual                                       NaN             NaN
# Year                                                 0.203309             NaN
# Happiness Rank                                      -0.522146        0.158516
# Whisker.high                                              NaN             NaN
# Whisker.low                                               NaN             NaN
# Family                                               0.053264       -0.120728
# Freedom                                              0.034829       -0.129773
# Trust..Government.Corruption.                             NaN             NaN
# Dystopia.Residual                                         NaN             NaN
# Lower Confidence Interval                            0.538793             NaN
# Upper Confidence Interval                            0.548164             NaN
# Trust (Government Corruption)                       -0.023504       -0.178325
# Dystopia Residual                                    1.000000        0.083981
# Standard Error                                       0.083981        1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# # The Top 3 Happiest and Least Happiest Countries

# %%
#what are the top 5 happiest countries and 5 least happy countries. 
#Is the "Happiness score" and "happiness rank" the same thing? #sort by happiest rank (ascending) 

top_happy= all_happiness_data.sort_values('Happiness Rank',ascending= True) 

print(top_happy)
# Out:
#                       Country              Region Happiness Score  \
# 0                     Finland                 NaN           7.769
# 0                      Norway                 NaN           7.537
# 0                 Switzerland      Western Europe           7.587
# 0                     Finland                 NaN           7.632
# 0                     Denmark      Western Europe           7.526
# ..                        ...                 ...             ...
# 148  Central African Republic  Sub-Saharan Africa  Happiness Rank
# 149                    Rwanda  Sub-Saharan Africa  Happiness Rank
# 150                  Zimbabwe  Sub-Saharan Africa  Happiness Rank
# 151               South Sudan  Sub-Saharan Africa  Happiness Rank
# 152               Afghanistan          South Asia  Happiness Rank
#
#      Standard error of ladder score  upperwhisker  lowerwhisker       GDP  \
# 0                               NaN           NaN           NaN  1.340000
# 0                               NaN           NaN           NaN  1.616463
# 0                               NaN           NaN           NaN  1.396510
# 0                               NaN           NaN           NaN  1.305000
# 0                               NaN           NaN           NaN  1.441780
# ..                              ...           ...           ...       ...
# 148                        0.115183      3.701658      3.250141  6.625160
# 149                        0.052425      3.415053      3.209547  7.600104
# 150                        0.058674      3.414202      3.184198  7.865712
# 151                        0.107610      3.027516      2.605684  7.425360
# 152                        0.031311      2.628270      2.505530  7.462861
#
#      Social support  Life Expectancy  Freedom to make life choices  ...  \
# 0          1.587000         0.986000                      0.596000  ...
# 0               NaN         0.796667                           NaN  ...
# 0               NaN         0.941430                           NaN  ...
# 0          1.592000         0.874000                      0.681000  ...
# 0               NaN         0.795040                           NaN  ...
# ..              ...              ...                           ...  ...
# 148        0.319460        45.200001                      0.640881  ...
# 149        0.540835        61.098846                      0.900589  ...
# 150        0.763093        55.617260                      0.711458  ...
# 151        0.553707        51.000000                      0.451314  ...
# 152        0.470367        52.590000                      0.396573  ...
#
#      Whisker.low    Family   Freedom  Trust..Government.Corruption.  \
# 0            NaN       NaN       NaN                            NaN
# 0       7.479556  1.533524  0.635423                       0.315964
# 0            NaN  1.349510  0.665570                            NaN
# 0            NaN       NaN       NaN                            NaN
# 0            NaN  1.163740  0.579410                            NaN
# ..           ...       ...       ...                            ...
# 148          NaN       NaN       NaN                            NaN
# 149          NaN       NaN       NaN                            NaN
# 150          NaN       NaN       NaN                            NaN
# 151          NaN       NaN       NaN                            NaN
# 152          NaN       NaN       NaN                            NaN
#
#      Dystopia.Residual  Lower Confidence Interval  Upper Confidence Interval  \
# 0                  NaN                        NaN                        NaN
# 0             2.277027                        NaN                        NaN
# 0                  NaN                        NaN                        NaN
# 0                  NaN                        NaN                        NaN
# 0                  NaN                       7.46                      7.592
# ..                 ...                        ...                        ...
# 148                NaN                        NaN                        NaN
# 149                NaN                        NaN                        NaN
# 150                NaN                        NaN                        NaN
# 151                NaN                        NaN                        NaN
# 152                NaN                        NaN                        NaN
#
#      Trust (Government Corruption)  Dystopia Residual  Standard Error
# 0                              NaN                NaN             NaN
# 0                              NaN                NaN             NaN
# 0                          0.41978            2.51738         0.03411
# 0                              NaN                NaN             NaN
# 0                          0.44453            2.73939             NaN
# ..                             ...                ...             ...
# 148                            NaN                NaN             NaN
# 149                            NaN                NaN             NaN
# 150                            NaN                NaN             NaN
# 151                            NaN                NaN             NaN
# 152                            NaN                NaN             NaN
#
# [935 rows x 33 columns]

# %%
#and view only country, happiness rank, and year. 

top_happy[['Country', 'Happiness Rank', 'Year']]
# Out:
#                       Country  Happiness Rank  Year
# 0                     Finland             1.0  2019
# 0                      Norway             1.0  2017
# 0                 Switzerland             1.0  2015
# 0                     Finland             1.0  2018
# 0                     Denmark             1.0  2016
# ..                        ...             ...   ...
# 148  Central African Republic             NaN  2020
# 149                    Rwanda             NaN  2020
# 150                  Zimbabwe             NaN  2020
# 151               South Sudan             NaN  2020
# 152               Afghanistan             NaN  2020
#
# [935 rows x 3 columns]

# %%
#sort by "Happiness score" (descending)

lowest_happy= all_happiness_data.sort_values('Happiness Rank', ascending= False)

print(lowest_happy)
# Out:
#                       Country                           Region  \
# 157                      Togo               Sub-Saharan Africa
# 156                   Burundi               Sub-Saharan Africa
# 156                   Burundi               Sub-Saharan Africa
# 155                     Syria  Middle East and Northern Africa
# 155                   Burundi                              NaN
# ..                        ...                              ...
# 148  Central African Republic               Sub-Saharan Africa
# 149                    Rwanda               Sub-Saharan Africa
# 150                  Zimbabwe               Sub-Saharan Africa
# 151               South Sudan               Sub-Saharan Africa
# 152               Afghanistan                       South Asia
#
#     Happiness Score  Standard error of ladder score  upperwhisker  \
# 157           2.839                             NaN           NaN
# 156           2.905                             NaN           NaN
# 156           2.905                             NaN           NaN
# 155           3.006                             NaN           NaN
# 155           2.905                             NaN           NaN
# ..              ...                             ...           ...
# 148  Happiness Rank                        0.115183      3.701658
# 149  Happiness Rank                        0.052425      3.415053
# 150  Happiness Rank                        0.058674      3.414202
# 151  Happiness Rank                        0.107610      3.027516
# 152  Happiness Rank                        0.031311      2.628270
#
#      lowerwhisker       GDP  Social support  Life Expectancy  \
# 157           NaN  0.208680             NaN         0.284430
# 156           NaN  0.015300             NaN         0.223960
# 156           NaN  0.068310             NaN         0.157470
# 155           NaN  0.663200             NaN         0.721930
# 155           NaN  0.091000        0.627000         0.145000
# ..            ...       ...             ...              ...
# 148      3.250141  6.625160        0.319460        45.200001
# 149      3.209547  7.600104        0.540835        61.098846
# 150      3.184198  7.865712        0.763093        55.617260
# 151      2.605684  7.425360        0.553707        51.000000
# 152      2.505530  7.462861        0.470367        52.590000
#
#      Freedom to make life choices  ...  Whisker.low   Family  Freedom  \
# 157                           NaN  ...          NaN  0.13995  0.36453
# 156                           NaN  ...          NaN  0.41587  0.11850
# 156                           NaN  ...          NaN  0.23442  0.04320
# 155                           NaN  ...          NaN  0.47489  0.15684
# 155                      0.065000  ...          NaN      NaN      NaN
# ..                            ...  ...          ...      ...      ...
# 148                      0.640881  ...          NaN      NaN      NaN
# 149                      0.900589  ...          NaN      NaN      NaN
# 150                      0.711458  ...          NaN      NaN      NaN
# 151                      0.451314  ...          NaN      NaN      NaN
# 152                      0.396573  ...          NaN      NaN      NaN
#
#      Trust..Government.Corruption.  Dystopia.Residual  \
# 157                            NaN                NaN
# 156                            NaN                NaN
# 156                            NaN                NaN
# 155                            NaN                NaN
# 155                            NaN                NaN
# ..                             ...                ...
# 148                            NaN                NaN
# 149                            NaN                NaN
# 150                            NaN                NaN
# 151                            NaN                NaN
# 152                            NaN                NaN
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 157                        NaN                        NaN
# 156                        NaN                        NaN
# 156                      2.732                      3.078
# 155                        NaN                        NaN
# 155                        NaN                        NaN
# ..                         ...                        ...
# 148                        NaN                        NaN
# 149                        NaN                        NaN
# 150                        NaN                        NaN
# 151                        NaN                        NaN
# 152                        NaN                        NaN
#
#      Trust (Government Corruption)  Dystopia Residual  Standard Error
# 157                        0.10731            1.56726         0.06727
# 156                        0.10062            1.83302         0.08658
# 156                        0.09419            2.10404             NaN
# 155                        0.18906            0.32858         0.05015
# 155                            NaN                NaN             NaN
# ..                             ...                ...             ...
# 148                            NaN                NaN             NaN
# 149                            NaN                NaN             NaN
# 150                            NaN                NaN             NaN
# 151                            NaN                NaN             NaN
# 152                            NaN                NaN             NaN
#
# [935 rows x 33 columns]

# %%
#and view only country, happiness rank, and year. 

lowest_happy[['Country', 'Happiness Rank', 'Year']]
# Out:
#                       Country  Happiness Rank  Year
# 157                      Togo           158.0  2015
# 156                   Burundi           157.0  2015
# 156                   Burundi           157.0  2016
# 155                     Syria           156.0  2015
# 155                   Burundi           156.0  2018
# ..                        ...             ...   ...
# 148  Central African Republic             NaN  2020
# 149                    Rwanda             NaN  2020
# 150                  Zimbabwe             NaN  2020
# 151               South Sudan             NaN  2020
# 152               Afghanistan             NaN  2020
#
# [935 rows x 3 columns]

# %% [markdown]
# # Adding Data From Other Datasets

# %% [markdown]
# Take happiest 3 countries and least happy 3 countires in the past 4 years and look up datasets for:
#
# - ethnic diversity
# - money spent on education 2015-2020 -  1 time series found: Afghanistan - Adjusted savings: education expenditure (% of GNI)
# - Percentage of women 2015-2020
# - are women in power?

# %% [markdown]
# # Top Three Happiest countries

# %% [markdown]
# # Finland

# %%
#Finland  

#ethnic diversity: 
#https://knoema.com/atlas/Finland/datasets
#https://worldpopulationreview.com/countries/finland-population

''''There are about 4,500 Sami left in Finland who are officially recognized as a minority. 
The Sami people have been living north of the Arctic Circle for over 7,000 years and account for a 5% minority in the 
Lapland Province. Finland does not keep official statistics on ethnicity.Just 3.5% of the population is
made up of foreign citizens, which is one of the lowest rates in the European Union. Most foreign citizens are 
from Estonia, Russia, and Sweden.'''

#Ratio of men to women: 
#https://worldpopulationreview.com/countries/finland-population
#https://knoema.com/atlas/Finland/topics/Demographics/Population/Male-to-female-ratio
''''In 2020, female population for Finland was 2.8 million persons. Female population of Finland increased 
from 2.38 million persons in 1971 to 2.8 million persons in 2020 growing at an average annual rate of 0.33%.'''
2021- female: 44.3
    
    
#percentage of women in government   


#Public spending on education as a share of gross domestic product
#https://knoema.com/atlas/Finland/topics/Education/Expenditures-on-Education/Public-spending-on-education-as-a-share-of-GDP

#Put data together in one table

#merge data

pd.merge()

#join data

result = pd.concat([df1, df4], axis=1, join="inner")

result = df1.append(df2)

# %% [markdown]
# # Norway

# %%
#Norway 

#ethnic diversity
#https://worldpopulationreview.com/countries/norway-population

''''The ethnicities in Norway are recorded as Norwegian 83.2% (includes about 60,000 Sami), 
other European 8.3%, other 8.5% by the Factbook as well.'''

#Ratio of men to women: 
#https://worldpopulationreview.com/countries/norway-population
40 percent female - 2021

#percentage of women in government

#spending on education

# %% [markdown]
# # Switzerland

# %%
#Switzerland

#ethnic diversity

#Ratio of men to women:

#percentage of women in government

#spending on education

# %% [markdown]
# # Top Three Unhappiest Countries

# %% [markdown]
# # Afghanistan

# %%
#ethnic diversity

#Ratio of men to women:

#percentage of women in government

#spending on education

# %%
Afghanistan_ = all_happiness_data.loc[all_happiness_data['Country'] == 'Afghanistan']

# %%
Afghanistan_[['Country', 'Happiness Rank', 'Year']]
# Out:
#          Country  Happiness Rank  Year
# 152  Afghanistan             NaN  2020
# 153  Afghanistan           154.0  2019
# 144  Afghanistan           145.0  2018
# 140  Afghanistan           141.0  2017
# 153  Afghanistan           154.0  2016
# 152  Afghanistan           153.0  2015

# %%
#education spending:
#https://knoema.com/WBWDI2019Jan/world-development-indicators-wdi
#1 time series found: Afghanistan - Adjusted savings: education expenditure (% of GNI)

Afghanistan_edu = pd.read_csv('ObservationData_gdtbbmg.csv')
# Out:
#        country                                             series Unit  Date  \
# 0  Afghanistan  Adjusted savings: education expenditure (% of ...    %  1970
# 1  Afghanistan  Adjusted savings: education expenditure (% of ...    %  1971
# 2  Afghanistan  Adjusted savings: education expenditure (% of ...    %  1972
# 3  Afghanistan  Adjusted savings: education expenditure (% of ...    %  1973
# 4  Afghanistan  Adjusted savings: education expenditure (% of ...    %  1974
#
#       Value
# 0  1.017778
# 1  1.000000
# 2  1.000000
# 3  1.300000
# 4  1.516893

# %%
#Afghanistan

#ethnic diversity: 


#Female to male Ratio
#https://knoema.com/atlas/Afghanistan/topics/Demographics/Population/Male-to-female-ratio 

DATE	VALUE	CHANGE, %
2020	105.40	-0.31 %
2015	105.73	0.87 %
2010	104.81	-1.72 %
2005	106.65	0.67 %
2000	105.94	-1.67 %
1995	107.74	3.04 %
1990	104.56	0.35 %
1985	104.20	0.82 %
1980	103.35	0.09 %
1975	103.26	-0.74 %
1970	104.02	-1.14 %
1965	105.22	


''''pip3 install knoema
import knoema
apicfg = knoema.ApiConfig()
apicfg.host = 'knoema.com'
apicfg.app_id = "some_app_id"
apicfg.app_secret = "some_app_secret"

knoema.get('UNWPP2019', frequency='A', Location='4', Gender='KN.G1', Age='KN.AG1', Variable='KN.AAF', Variant='KN.ESTV')'''    
    
    
#percentage of women in power
# Out:
#   File "<ipython-input-139-6a1549e00101>", line 7
#     pip3 install knoema
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # South Sudan

# %%
#South Sudan

#ethnic diversity

#Ratio of men to women:

#percentage of women in government

#spending on education

# %% [markdown]
# # Zimbabwe

# %%
#Zimbabwe

#ethnic diversity

#Ratio of men to women:

#percentage of women in government

#spending on education

# %% [markdown]
# # Data Organization
#
# - Goal: Create a file structure and add your work to the GitHub repository you’ve created for this project.
# - Hint: the glob library could come in handy here…
# - Remind yourself of why GitHub is useful. What are the main motivations for making a GitHub repository?

# %%
#File structure

C:\Users\Allegra Grunberg/Downloads/archive (1)

# %%
#GitHub

# %% [markdown]
# # Extra Notes
#
# #import data
#
# ski_data = pd.read_csv( 'ski_resort_data-Copy1.csv')
#
# #Call the info method on ski_data to see a summary of the data
# ski_data.info()
#
# do .shape and .head()
#
# take out nans
#
# #filter
# ski_data[ski_data.Name == 'Big Mountain Resort'].T
#
# ● Data Collection
# Organize your data to streamline the next steps of your
# capstone
# Data loading
# ■ Data joining
# ■ Hint: Data Collection will require the use of the pandas library,
# and functions like read_csv() , depending on the type of data
# you want to read in!
# ■ Hint: when adding one dataset to another, make sure you use
# the right function: you might want to merge, join, or
# concatenate
#
# import pandas as pd
# import os
#
# df= pd.read_csv('Metro_Interstate_Traffic_Volume.csv')
# df.rain_1h.rename('rain')
# df2 = df.rename(index=str, columns={"rain_1h":"Rain", "snow_1h":"Snow"})
# def kelv_to_fahr(temp_kelv):
#     temp_fahr = ((temp_kelv - 273.15) * (9/5)) + 32
#     return temp_fahr
#
# df2["temp"] = kelv_to_fahr(df2["temp"])
# print(df2)
#
# # https://ddf46429.springboard.com/uploads/resources/1596215165_Guided_Capstone_Rubric___Step_2.docx.pdf
#
#
# pandas
# data ingestion and inspection (pandas Foundations, Module One)
# exploratory data analysis (pandas Foundations, Module Two)
# tidying and cleaning (Manipulating DataFrames with pandas, Module Three)
# transforming DataFrames (Manipulating DataFrames with pandas, Module One)
# subsetting DataFrames with lists (Manipulating DataFrames with pandas, Module One)
# filtering DataFrames (Manipulating DataFrames with pandas, Module One)
# grouping data (Manipulating DataFrames with pandas, Module Four)
# melting data (Manipulating DataFrames with pandas, Module Three)
# advanced indexing (Manipulating DataFrames with pandas, Module Four)
# matplotlib (Intermediate Python for Data Science, Module One)
# fundamental data types (Data Types for Data Science, Module One)
# dictionaries (Intermediate Python for Data Science, Module Two)
# handling dates and times (Data Types for Data Science, Module Four)
# function definition (Python Data Science Toolbox - Part One, Module One)
# default arguments, variable length, and scope (Python Data Science Toolbox - Part One, Module Two)
# lambda functions and error handling (Python Data Science Toolbox - Part One, Module Four)
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
#
# Sourcing and loading
# Cleaning, transforming, and visualizing
# Modeling
# Evaluating and concluding
#
# ]
#
# # Import modules
# import pandas as pd
#
# # Read colors data
# colors = pd.read_csv('colors.csv')
#
# # Print the first few rows
# colors.head()
#
#
# df_offers.columns = ["offer_id", "campaign", "varietal", "min_qty", "discount", "origin", "past_peak"]
# df_offers.head()

# %%
#longhand stats



 #Mean
numb_column1 =pd['Diversion Rate-Total (Total Recycling / Total Waste)']
mean_1 = statistics.mean(numb_column1) 
print("First column Mean is :", mean_1)

 #median
median_1= statistics.median(numb_column1)
print("First column median is:",median_1)

 #mode 
mode_1= statistics.mode(numb_column1)
print("First column mode is:",mode_1)

 #std
std_1= statistics.stdev(numb_column1)
print("First column standard dev is:",std_1)  

max(numb_column1)

 #range
    
#range(start, stop, step)
range_1= range(0, 34, 1)
print("First column range is:",range_1)  

 #unique
#unique_1= wall['title'].value_counts().unique()
unique_1= numb_column1.value_counts().unique()
print("First column uinque numbers:",unique_1)

# %%
● Data Organization
○ Goal: Create a file structure and add your work to the GitHub
repository you’ve created for this project.
○ Time estimate: 1-2 hours
■ File structure
■ GitHub
■ Hint: the glob library could come in handy here…
■ Remind yourself of why GitHub is useful. What are the main
motivations for making a GitHub repository?

# %%
● Data Definition
○ Goal: Gain an understanding of your data features to inform the
next steps of your project.
○ Time estimate: 1-2 hours
■ Column names
■ Data types
■ Description of the columns
■ Counts and percents unique values
■ Ranges of values
- Hint: here are some useful questions to ask yourself during this
process:
- Do your column names correspond to what those columns
store?
- Check the data types of your columns. Are they sensible?
- Calculate summary statistics for each of your columns, such
as mean, median, mode, standard deviation, range, and
number of unique values. What does this tell you about your
data? What do you now need to investigate?

#Code task 17#
#Call ski_data's `describe` method for a statistical summary of the numerical columns
#Hint: there are fewer summary stat columns than features, so displaying the transpose
#will be useful again

ski_data.describe().T
